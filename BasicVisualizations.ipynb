# %%
import pandas as pd
import numpy as np
import seaborn as sns
import csv
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("epa_hap_daily_summary.csv")
data.head()
# Out:
#    state_code  county_code  site_num  parameter_code  poc   latitude  \
# 0          42          125      5001           88103    5  40.445278
# 1          48          439      1002           43843   15  32.805818
# 2          22          127      9000           88128    1  32.057581
# 3          18           89        22           45201    1  41.606680
# 4           6           89      3003           88136    1  40.539990
#
#     longitude  datum      parameter_name sample_duration         ...           \
# 0  -80.420833  WGS84    Arsenic PM2.5 LC         24 HOUR         ...
# 1  -97.356568  WGS84  Ethylene dibromide         24 HOUR         ...
# 2  -92.435157  WGS84       Lead PM2.5 LC         24 HOUR         ...
# 3  -87.304729  WGS84             Benzene          1 HOUR         ...
# 4 -121.576460  NAD83     Nickel PM2.5 LC         24 HOUR         ...
#
#    aqi method_code                                        method_name  \
# ...

# %%
for state in data[]

# %%
data = data[["latitude", "longitude", "parameter_name", "date_local", "units_of_measure", "arithmetic_mean"]]
data.dropna()
data.head()
# Out:
#     latitude   longitude      parameter_name  date_local  \
# 0  40.445278  -80.420833    Arsenic PM2.5 LC  2005-12-30
# 1  32.805818  -97.356568  Ethylene dibromide  2013-09-19
# 2  32.057581  -92.435157       Lead PM2.5 LC  2001-11-12
# 3  41.606680  -87.304729             Benzene  2016-05-23
# 4  40.539990 -121.576460     Nickel PM2.5 LC  2001-08-02
#
#               units_of_measure  arithmetic_mean
# 0  Micrograms/cubic meter (LC)         0.003000
# 1     Parts per billion Carbon         0.000000
# 2  Micrograms/cubic meter (LC)         0.002280
# 3     Parts per billion Carbon         0.413913
# 4  Micrograms/cubic meter (LC)         0.000130

# %%
# dataSamp = data.sample(100000)
dataSamp = data[data["parameter_name"] == "Benzene"].sample(1000)
dataSamp.head()
# Out:
#      latitude   longitude parameter_name  date_local  \
# 3   41.606680  -87.304729        Benzene  2016-05-23
# 25  39.297733  -76.604603        Benzene  2006-08-15
# 51  40.694540  -73.927690        Benzene  2003-01-27
# 62  41.807776  -71.415105        Benzene  2006-12-07
# 84  37.687526 -121.784217        Benzene  2012-10-26
#
#             units_of_measure  arithmetic_mean
# 3   Parts per billion Carbon         0.413913
# 25  Parts per billion Carbon         1.200000
# 51  Parts per billion Carbon         2.500000
# 62  Parts per billion Carbon         1.962000
# 84  Parts per billion Carbon         1.799496

# %%
sns.regplot("latitude", "arithmetic_mean", data=dataSamp)

# %%
plt.scatter(x = dataSamp["latitude"], y = dataSamp["longitude"], c = dataSamp["arithmetic_mean"], alpha = 0.3)

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt 
plt.rc("font", size=14)
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import train_test_split
import seaborn as sns
sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)
# Out:
# C:\Users\ndeas\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from mpl_toolkits.basemap import Basemap
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-d9467465a3b6> in <module>()
# ----> 1 from mpl_toolkits.basemap import Basemap
#
# ModuleNotFoundError: No module named 'mpl_toolkits.basemap'
